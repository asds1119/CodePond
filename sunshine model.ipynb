# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import sklearn as sns

# %%
df=pd.read_csv("D:\Sunshine hours for cities in the world.csv")

# %%
pip install matplotlib
# Out:
# ...
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# ...
#      ---------------------------------------- 0.0/162.8 kB ? eta -:--:--
#      ---------------------------------------- 0.0/162.8 kB ? eta -:--:--
#      -- ------------------------------------- 10.2/162.8 kB ? eta -:--:--
#      -- ------------------------------------- 10.2/162.8 kB ? eta -:--:--
#      --------- --------------------------- 41.0/162.8 kB 326.8 kB/s eta 0:00:01
#      ------------------ ------------------ 81.9/162.8 kB 512.0 kB/s eta 0:00:01
#      --------------------------------- -- 153.6/162.8 kB 766.6 kB/s eta 0:00:01
#      ------------------------------------ 162.8/162.8 kB 751.3 kB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/7.7 MB ? eta -:--:--
#     --------------------------------------- 0.2/7.7 MB 10.2 MB/s eta 0:00:01
#    - -------------------------------------- 0.3/7.7 MB 4.2 MB/s eta 0:00:02
# ...

# %%
pip install scikit-learn
# Out:
# ...
#      ---------------------------------------- 0.0/60.6 kB ? eta -:--:--
#      ---------------------------------------- 0.0/60.6 kB ? eta -:--:--
#      ---------------------------------------- 0.0/60.6 kB ? eta -:--:--
#      ---------------------------------------- 0.0/60.6 kB ? eta -:--:--
#      ---------------------------------------- 0.0/60.6 kB ? eta -:--:--
#      ------ --------------------------------- 10.2/60.6 kB ? eta -:--:--
#      ------ --------------------------------- 10.2/60.6 kB ? eta -:--:--
#      ------------------- ------------------ 30.7/60.6 kB 187.9 kB/s eta 0:00:01
#      ------------------- ------------------ 30.7/60.6 kB 187.9 kB/s eta 0:00:01
#      ------------------- ------------------ 30.7/60.6 kB 187.9 kB/s eta 0:00:01
#      ------------------- ------------------ 30.7/60.6 kB 187.9 kB/s eta 0:00:01
#      ------------------- ------------------ 30.7/60.6 kB 187.9 kB/s eta 0:00:01
# ...

# %%
df
# Out:
#          Country        City    Jan    Feb    Mar    Apr    May    Jun    Jul  \
# 0    Ivory Coast      Gagnoa  183.0  180.0  196.0  188.0  181.0  118.0   97.0
# 1    Ivory Coast      Bouaké  242.0  224.0  219.0  194.0  208.0  145.0  104.0
# 2    Ivory Coast     Abidjan  223.0  223.0  239.0  214.0  205.0  128.0  137.0
# 3    Ivory Coast     Odienné  242.0  220.2  217.3  214.7  248.8  221.8  183.5
# 4    Ivory Coast       Ferké  279.0  249.0  253.0  229.0  251.0  221.0  183.0
# ..           ...         ...    ...    ...    ...    ...    ...    ...    ...
# 387  New Zealand  Wellington  240.3  205.0  194.7  153.8  126.0  102.3  111.4
# 388  New Zealand    Hamilton  229.8  192.9  193.3  165.1  138.3  112.8  126.4
# 389  New Zealand    Auckland  228.8  194.9  189.2  157.3  139.8  110.3  128.1
# 390         Fiji        Suva  192.2  178.0  170.5  153.0  145.7  141.0  136.4
# 391  New Zealand     Dunedin  179.6  158.0  146.1  125.9  108.4   95.3  110.6
#
# ...

# %%
df.isnull()
# Out:
#      Country   City    Jan    Feb    Mar    Apr    May    Jun    Jul    Aug  \
# 0      False  False  False  False  False  False  False  False  False  False
# 1      False  False  False  False  False  False  False  False  False  False
# 2      False  False  False  False  False  False  False  False  False  False
# 3      False  False  False  False  False  False  False  False  False  False
# 4      False  False  False  False  False  False  False  False  False  False
# ..       ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 387    False  False  False  False  False  False  False  False  False  False
# 388    False  False  False  False  False  False  False  False  False  False
# 389    False  False  False  False  False  False  False  False  False  False
# 390    False  False  False  False  False  False  False  False  False  False
# 391    False  False  False  False  False  False  False  False  False  False
#
#        Sep    Oct    Nov    Dec   Year
# ...

# %%
df.isnull().sum()
# Out:
# Country    0
# City       0
# Jan        0
# Feb        0
# Mar        0
# Apr        0
# May        0
# Jun        0
# Jul        0
# Aug        0
# Sep        0
# Oct        0
# Nov        0
# Dec        0
# Year       0
# dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# 0

# %%
df.shape
# Out:
# (392, 15)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 392 entries, 0 to 391
# Data columns (total 15 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Country  392 non-null    object
#  1   City     392 non-null    object
#  2   Jan      392 non-null    float64
#  3   Feb      392 non-null    float64
#  4   Mar      392 non-null    float64
#  5   Apr      392 non-null    float64
#  6   May      392 non-null    float64
#  7   Jun      392 non-null    float64
#  8   Jul      392 non-null    float64
#  9   Aug      392 non-null    float64
#  10  Sep      392 non-null    float64
#  11  Oct      392 non-null    float64
#  12  Nov      392 non-null    float64
#  13  Dec      392 non-null    float64
#  14  Year     392 non-null    float64
# dtypes: float64(13), object(2)
# memory usage: 46.1+ KB

# %%
df.head(50)
# Out:
#          Country           City    Jan    Feb    Mar    Apr    May    Jun  \
# 0    Ivory Coast         Gagnoa  183.0  180.0  196.0  188.0  181.0  118.0
# 1    Ivory Coast         Bouaké  242.0  224.0  219.0  194.0  208.0  145.0
# 2    Ivory Coast        Abidjan  223.0  223.0  239.0  214.0  205.0  128.0
# 3    Ivory Coast        Odienné  242.0  220.2  217.3  214.7  248.8  221.8
# 4    Ivory Coast          Ferké  279.0  249.0  253.0  229.0  251.0  221.0
# 5          Benin        Cotonou  213.9  210.0  223.2  219.0  213.9  141.0
# 6          Benin        Parakou  261.0  243.0  252.0  230.0  239.0  193.0
# 7          Benin          Kandi  279.0  257.6  260.4  255.0  272.8  252.0
# 8           Togo           Lomé  217.5  214.0  227.9  201.9  208.6  146.0
# 9           Togo          Mango  285.0  254.0  270.0  241.0  261.0  219.0
# 10         Ghana          Accra  217.0  226.0  217.0  210.0  217.0  150.0
# 11         Ghana         Tamale  265.6  235.7  249.6  229.0  248.0  212.0
# ...

# %%
from sklearn.preprocessing import LabelEncoder
Le=LabelEncoder()

df['Country']=Le.fit_transform(df['Country'])
df['City']=Le.fit_transform(df['City'])

# %%
df.head(50)
# Out:
#     Country  City    Jan    Feb    Mar    Apr    May    Jun    Jul    Aug  \
# 0        66   130  183.0  180.0  196.0  188.0  181.0  118.0   97.0   80.0
# 1        66    54  242.0  224.0  219.0  194.0  208.0  145.0  104.0   82.0
# 2        66     2  223.0  223.0  239.0  214.0  205.0  128.0  137.0  125.0
# 3        66   260  242.0  220.2  217.3  214.7  248.8  221.8  183.5  174.5
# 4        66   122  279.0  249.0  253.0  229.0  251.0  221.0  183.0  151.0
# 5        12    92  213.9  210.0  223.2  219.0  213.9  141.0  136.4  148.8
# 6        12   270  261.0  243.0  252.0  230.0  239.0  193.0  133.0  104.0
# 7        12   164  279.0  257.6  260.4  255.0  272.8  252.0  223.2  195.3
# 8       127   191  217.5  214.0  227.9  201.9  208.6  146.0  141.6  148.8
# 9       127   210  285.0  254.0  270.0  241.0  261.0  219.0  168.0  131.0
# 10       51     4  217.0  226.0  217.0  210.0  217.0  150.0  155.0  155.0
# 11       51   337  265.6  235.7  249.6  229.0  248.0  212.0  171.5  139.0
# ...

# %%
df['Country']=Le.fit_transform(df['Country'])

# %%
x=df.drop('Year',axis=1)

# %%
x.head(30)
# Out:
#     Country  City    Jan    Feb    Mar    Apr    May    Jun    Jul    Aug  \
# 0        66   130  183.0  180.0  196.0  188.0  181.0  118.0   97.0   80.0
# 1        66    54  242.0  224.0  219.0  194.0  208.0  145.0  104.0   82.0
# 2        66     2  223.0  223.0  239.0  214.0  205.0  128.0  137.0  125.0
# 3        66   260  242.0  220.2  217.3  214.7  248.8  221.8  183.5  174.5
# 4        66   122  279.0  249.0  253.0  229.0  251.0  221.0  183.0  151.0
# 5        12    92  213.9  210.0  223.2  219.0  213.9  141.0  136.4  148.8
# 6        12   270  261.0  243.0  252.0  230.0  239.0  193.0  133.0  104.0
# 7        12   164  279.0  257.6  260.4  255.0  272.8  252.0  223.2  195.3
# 8       127   191  217.5  214.0  227.9  201.9  208.6  146.0  141.6  148.8
# 9       127   210  285.0  254.0  270.0  241.0  261.0  219.0  168.0  131.0
# 10       51     4  217.0  226.0  217.0  210.0  217.0  150.0  155.0  155.0
# 11       51   337  265.6  235.7  249.6  229.0  248.0  212.0  171.5  139.0
# ...

# %%
y=df.Year

# %%
y
# Out:
# 0      1823.0
# 1      2092.0
# 2      2296.0
# 3      2638.6
# 4      2757.0
#         ...
# 387    2058.7
# 388    2019.6
# 389    2003.1
# 390    1922.0
# 391    1683.7
# Name: Year, Length: 392, dtype: float64

# %%
y.head(30)
# Out:
# 0     1823.0
# 1     2092.0
# 2     2296.0
# 3     2638.6
# 4     2757.0
# 5     2345.2
# 6     2501.0
# 7     3045.2
# 8     2333.9
# 9     2826.0
# 10    2432.0
# 11    2718.7
# 12    1951.8
# 13    2927.1
# 14    2471.4
# 15    1618.0
# 16    1644.0
# 17    1716.6
# 18    1723.8
# 19    1845.4
# 20    2380.0
# 21    2768.0
# 22    3114.0
# 23    3238.0
# 24    3382.0
# 25    3737.1
# 26    3361.0
# 27    3136.0
# 28    3282.0
# 29    3203.2
# Name: Year, dtype: float64

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)

# %%
len(x_train)
# Out:
# 313

# %%
from sklearn import linear_model

# %%
model=linear_model.LinearRegression()

# %%
model
# Out:
# LinearRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
Var1=model.score(x_test,y_test)

# %%
Var1
# Out:
# 0.999865385970752

# %%
import joblib

# %%
joblib.dump(model,"sunshine_model.pkl")
# Out:
# ['sunshine_model.pkl']

# %%
model2=joblib.load("sunshine_model.pkl")

# %%
model2.predict(x_train)
# Out:
# array([2771.41034875, 3763.94429795, 2589.87677691, 3518.59426429,
#        2108.2032035 , 2062.99944646, 1662.04999477, 1913.03537666,
#        2847.52440353, 1589.29077721, 1745.42682608, 3506.66011681,
#        1644.78740982, 3122.49806634, 2641.85970491, 2042.24698971,
#        4019.02094527, 2508.30967664, 1567.79442691, 2471.86152351,
#        1837.95202735, 2341.47190002, 1874.67114621, 2796.12675749,
#        3244.24313866, 2734.01236591, 1862.48289616, 3091.78578629,
#        2973.75011794, 2281.11204318, 2954.53264261, 2997.68779589,
#        2662.24341541, 2930.73885289, 2322.78040859, 2184.07264698,
#        2225.66404479, 2497.42638266, 2820.37621294, 2061.22698932,
#        2803.6353862 , 2070.04769007, 2711.36219125, 2894.85494618,
#        2358.67749195, 2291.22799592, 3945.11498775, 2441.0471754 ,
#        3566.70735188, 2996.79950482, 3848.08966021, 1182.10417964,
#        1824.5918056 , 2362.53086318, 2690.6100124 , 1171.66326804,
# ...

# %%
model2.predict(x_test)
# Out:
# array([1630.60459797, 3034.06307294, 2935.60598741, 3219.96223691,
#        1943.02042922, 3177.34137881, 2466.19231526, 1922.12133428,
#        1857.10396093, 3584.46968448, 2213.05276839, 2574.38298367,
#        3565.5698658 , 1772.51185824, 2378.5058879 , 3610.06571767,
#        3081.88829161, 2865.21470579, 1913.55961267, 2376.45674399,
#        1668.4078853 , 2508.63251305, 2069.27781285, 1484.624215  ,
#        3009.80499928, 3165.9836385 , 2231.84107301, 2241.14404399,
#        3109.49072185, 1729.25371617, 2683.04306348, 1166.64745928,
#        2313.86202658, 2327.26695484, 3340.67852547, 2682.16685304,
#        3155.41684858, 3046.44179656, 1721.75105137, 1581.45395209,
#        3219.84598323, 2232.74905262, 1282.1410222 , 3495.86101004,
#        1869.2478097 , 3288.06758224, 2577.01983477, 3829.99227983,
#        2841.79448128, 1324.80107968, 2235.19980215, 2626.64375242,
#        3612.94520846, 2930.0558206 , 2436.8046599 , 2719.23622846,
# ...

# %%
import pickle

# Open the file in binary mode
with open("C:\Users\Anushka   Singh\sunshine_model.pkl"rb) as f:
    model = pickle.load(f)

# Now you can use the loaded model as needed
# Out:
#   Cell In[38], line 4
#     with open("C:\Users\Anushka   Singh\sunshine_model.pkl"rb) as f:
#                                                            ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape

# %%
import pickle

# Using a raw string
with open(r"C:\Users\Anushka Singh\sunshine_model.pkl", 'rb') as f:
    model = pickle.load(f)

# Or, escaping the backslashes
with open("C:\\Users\\Anushka Singh\\sunshine_model.pkl", 'rb') as f:
    model = pickle.load(f)

# Now you can use the loaded model as needed
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[39], line 4
#       1 import pickle
#       3 # Using a raw string
# ----> 4 with open(r"C:\Users\Anushka Singh\sunshine_model.pkl", 'rb') as f:
#       5     model = pickle.load(f)
#       7 # Or, escaping the backslashes
#
# File ~\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py:310, in _modified_open(file, *args, **kwargs)
#     303 if file in {0, 1, 2}:
#     304     raise ValueError(
#     305         f"IPython won't let you open fd={file} by default "
#     306         "as it is likely to crash IPython. If you know what you are doing, "
#     307         "you can use builtins' open."
#     308     )
# --> 310 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'C:\\Users\\Anushka Singh\\sunshine_model.pkl'
